# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as image
plt.style.use('ggplot')

from skimage import io
from sklearn.cluster import KMeans

from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider
import ipywidgets as widgets

# %%
plt.rcParams['figure.figsize'] = (20, 12)

# %% [markdown]
# ### Data Preprocessing

# %%
img = io.imread('images/1-St-Basils-Cathedral.jpg')
ax = plt.axes(xticks=[], yticks=[])
ax.imshow(img);

# %%
img.shape
# Out:
# (3596, 2877, 3)

# %%
img_data = (img / 255.0).reshape(-1, 3) # (img / 255.0).reshape(img.shape[0]*img.shape[1], 3)
img_data.shape
# Out:
# (10345692, 3)

# %% [markdown]
# ### Visualizing the Color Space using Point Clouds

# %%
from plot_utils import plot_utils

# %%
x = plot_utils(img_data, title="Input color space: Over 16 million possible colors")
x.colorSpace()
